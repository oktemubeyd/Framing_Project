# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 3.5 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 15.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import Dataset, DataLoader
import torch
from torch.optim import AdamW
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_recall_fscore_support
import numpy as np
import re
import optuna

# %%
df = pd.read_excel("competition_cooperation_annotations.xlsx")[['Body', 'SRF_Cooperation']]

# %%
df
# Out:
#                                                   Body  SRF_Cooperation
# 0    \n                Çin Dışişleri Bakanlığından ...                1
# 1    \n                Nurdoğan ARSLAN ERGÜN_x000D_...                0
# 2    \n                Hamide HANGÜL_x000D_\nKalifi...                0
# 3    \n                Ege İhracatçı Birlikleri, 5 ...                1
# 4    \n                Türkiye’nin en sevilen marka...                1
# ..                                                 ...              ...
# 199  Çinli turistlerin Türkiye'de yaptığı alışveriş...                1
# 200  TÜSİAD, BRICA Zirvesi'ne ev sahipliği yapacakÇ...                1
# 201  'Çelikte Çin'in geri kalacağı pazarlardaki tal...                0
# 202  Aksa Jeneratör ile Mitsubishi ortak şirket kur...                1
# 203  VakıfBank’a Çin’den 140 milyon dolar kaynakVak...                1
#
# [204 rows x 2 columns]

# %%
df['Body'] = df['Body'].replace([None, ''], pd.NA)
df = df.dropna()

df['SRF_Cooperation'] = df['SRF_Cooperation'].replace([None, ''], pd.NA)
df = df.dropna()

# %%
df.groupby('SRF_Cooperation').count()
# Out:
#                  Body
# SRF_Cooperation
# 0                  61
# 1                 143

# %%
# Split data into features and labels
texts = df['Body'].tolist()
labels = df['SRF_Cooperation'].tolist()

# %% [markdown]
# ## BERT Model

# %%
tokenizer = BertTokenizer.from_pretrained('dbmdz/bert-base-turkish-128k-cased')

class NewspaperDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=512):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
            truncation=True
        )

        return {
            'text': text,
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.18M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/386 [00:00<?, ?B/s]

# %%
# Define training and evaluation functions
def train_epoch(model, data_loader, optimizer, device, n_examples):
    model.train()
    losses = []
    correct_predictions = 0

    for d in data_loader:
        input_ids = d['input_ids'].to(device)
        attention_mask = d['attention_mask'].to(device)
        labels = d['labels'].to(device)

        optimizer.zero_grad()

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)

        _, preds = torch.max(outputs.logits, dim=1)
        loss = outputs.loss

        correct_predictions += torch.sum(preds == labels)
        losses.append(loss.item())

        loss.backward()
        optimizer.step()

    return correct_predictions.double() / n_examples, sum(losses) / n_examples

def eval_model(model, data_loader, device, n_examples):
    model.eval()
    losses = []
    correct_predictions = 0
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for d in data_loader:
            input_ids = d['input_ids'].to(device)
            attention_mask = d['attention_mask'].to(device)
            labels = d['labels'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)

            _, preds = torch.max(outputs.logits, dim=1)
            loss = outputs.loss

            correct_predictions += torch.sum(preds == labels)
            losses.append(loss.item())

            all_predictions.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct_predictions.double() / n_examples
    avg_loss = sum(losses) / n_examples
    class_report = classification_report(all_labels, all_predictions, output_dict=True)
    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # ✅ Now returns five values including predictions
    return accuracy, avg_loss, class_report, conf_matrix, all_predictions

# %%
# Device setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data split
train_idx, val_idx = train_test_split(
    list(range(len(texts))), test_size=0.3, stratify=labels, random_state=2
)
train_texts = [texts[i] for i in train_idx]
val_texts = [texts[i] for i in val_idx]
train_labels = [labels[i] for i in train_idx]
val_labels = [labels[i] for i in val_idx]

from sklearn.metrics import precision_recall_fscore_support, confusion_matrix

def objective(trial):
    # Sample hyperparameters
    learning_rate = trial.suggest_float("lr", 1e-5, 5e-5, log=True)
    batch_size = trial.suggest_categorical("batch_size", [8, 16, 32])
    num_epochs = trial.suggest_int("num_epochs", 3, 6)
    seed = trial.suggest_int("seed", 1, 10000)

    # Set all seeds
    import random, os
    import numpy as np
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(seed)

    # Prepare data
    train_dataset = NewspaperDataset(train_texts, train_labels, tokenizer)
    val_dataset = NewspaperDataset(val_texts, val_labels, tokenizer)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model
    model = BertForSequenceClassification.from_pretrained(
        'dbmdz/bert-base-turkish-128k-cased', num_labels=2
    ).to(device)
    optimizer = AdamW(model.parameters(), lr=learning_rate)

    # Train
    for epoch in range(num_epochs):
        train_epoch(model, train_loader, optimizer, device, len(train_dataset))

    # Evaluate
    _, _, _, _, val_preds = eval_model(model, val_loader, device, len(val_dataset))
    val_true = [val_labels[i] for i in range(len(val_preds))]

    # Per-class precision, recall, f1
    precision, recall, f1, support = precision_recall_fscore_support(val_true, val_preds, average=None, labels=[0,1])
    f1_macro = f1.mean()
    f2_class_1 = (5 * precision[1] * recall[1]) / (4 * precision[1] + recall[1] + 1e-10)

    # Confusion Matrix
    conf = confusion_matrix(val_true, val_preds, labels=[0, 1])
    tn, fp, fn, tp = conf.ravel()

    # Optional: log metrics as trial attributes (can be accessed later)
    trial.set_user_attr("precision_0", precision[0])
    trial.set_user_attr("recall_0", recall[0])
    trial.set_user_attr("precision_1", precision[1])
    trial.set_user_attr("recall_1", recall[1])
    trial.set_user_attr("f1_macro", f1_macro)
    trial.set_user_attr("f2_class_1", f2_class_1)
    trial.set_user_attr("conf_matrix", conf.tolist())  # so it's serializable
    trial.set_user_attr("seed", seed)

    return f1_macro, f2_class_1  # still optimizing these



# Multi-objective study
study = optuna.create_study(directions=["maximize", "maximize"])
study.optimize(objective, n_trials=50)

# Show top trials
print("\n✅ Top Trials (F1-macro & F2-class1):")
for i, t in enumerate(study.best_trials):
    print(f"\nTrial {i}")
    print(f"F1-macro: {t.values[0]:.4f}, F2 (class 1): {t.values[1]:.4f}")
    print(f"Precision (0): {t.user_attrs['precision_0']:.4f}, Recall (0): {t.user_attrs['recall_0']:.4f}")
    print(f"Precision (1): {t.user_attrs['precision_1']:.4f}, Recall (1): {t.user_attrs['recall_1']:.4f}")
    print(f"Seed: {t.user_attrs['seed']}")
    print("Confusion Matrix:")
    print(np.array(t.user_attrs["conf_matrix"]))

# Optionally pick the one with highest F1 or F2
best_trial = max(study.best_trials, key=lambda t: t.values[0])  # or `t.values[1]` for F2
best_params = best_trial.params
print("\n🎯 Using best trial based on F1:")
print(f"  F1 = {best_trial.values[0]:.4f}, F2 = {best_trial.values[1]:.4f}")
print(f"  Params = {best_params}")

# Final model training with best params
final_model = BertForSequenceClassification.from_pretrained(
    'dbmdz/bert-base-turkish-128k-cased', num_labels=2
).to(device)
final_optimizer = AdamW(final_model.parameters(), lr=best_params["lr"])

train_dataset = NewspaperDataset(train_texts, train_labels, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=best_params["batch_size"], shuffle=True)

for epoch in range(best_params["num_epochs"]):
    train_epoch(final_model, train_loader, final_optimizer, device, len(train_dataset))

torch.save(final_model.state_dict(), 'bert_cooperation_model_optimized_dual.pth')
print("\n✅ Final model saved as 'bert_cooperation_model_optimized_dual.pth'")
# Out:
# [I 2025-04-16 08:45:39,027] A new study created in memory with name: no-name-dd1a4606-c3c8-41be-b187-b28ac496b390
# model.safetensors:   0%|          | 0.00/740M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:46:02,102] Trial 0 finished with values: [0.7524500907441016, 0.9374999999777183] and parameters: {'lr': 1.6969134658511704e-05, 'batch_size': 32, 'num_epochs': 6, 'seed': 6130}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:46:12,331] Trial 1 finished with values: [0.6383333333333333, 0.9388646287975915] and parameters: {'lr': 1.3316275097287096e-05, 'batch_size': 8, 'num_epochs': 3, 'seed': 7497}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:46:29,513] Trial 2 finished with values: [0.8042929292929293, 0.8986175115001912] and parameters: {'lr': 4.7708236451759713e-05, 'batch_size': 32, 'num_epochs': 6, 'seed': 4649}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:46:44,064] Trial 3 finished with values: [0.6242424242424243, 0.9210526315557863] and parameters: {'lr': 1.0474098828933264e-05, 'batch_size': 32, 'num_epochs': 5, 'seed': 9881}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:47:03,112] Trial 4 finished with values: [0.6482269503546099, 0.8744394618613586] and parameters: {'lr': 1.3006817549272308e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 1779}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:47:13,284] Trial 5 finished with values: [0.6449026345933562, 0.9070796459949684] and parameters: {'lr': 1.0701800471284578e-05, 'batch_size': 8, 'num_epochs': 3, 'seed': 922}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:47:32,336] Trial 6 finished with values: [0.9004815409309791, 0.9633027522727673] and parameters: {'lr': 3.118715542971209e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 8425}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:47:48,781] Trial 7 finished with values: [0.8434343434343434, 0.9216589861545692] and parameters: {'lr': 1.6797838912816488e-05, 'batch_size': 8, 'num_epochs': 5, 'seed': 7342}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:48:01,028] Trial 8 finished with values: [0.512713823393435, 0.9267241379070675] and parameters: {'lr': 1.1037965896206033e-05, 'batch_size': 16, 'num_epochs': 4, 'seed': 2181}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:48:20,064] Trial 9 finished with values: [0.8315217391304348, 0.9502262443223213] and parameters: {'lr': 2.293814760286653e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 4458}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:48:29,560] Trial 10 finished with values: [0.7232142857142857, 0.9333333333108247] and parameters: {'lr': 4.3263481228717976e-05, 'batch_size': 16, 'num_epochs': 3, 'seed': 3968}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:48:48,608] Trial 11 finished with values: [0.7395952653684612, 0.9513274336055877] and parameters: {'lr': 1.9765734091766796e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 5651}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:49:00,424] Trial 12 finished with values: [0.5866666666666667, 0.9170305676622204] and parameters: {'lr': 1.201075673577564e-05, 'batch_size': 32, 'num_epochs': 4, 'seed': 8500}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:49:19,507] Trial 13 finished with values: [0.7361702127659575, 0.9192825111887128] and parameters: {'lr': 1.551468836297666e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 290}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:49:38,531] Trial 14 finished with values: [0.7074410163339383, 0.9151785714062898] and parameters: {'lr': 1.7899979859114487e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 3917}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:49:57,564] Trial 15 finished with values: [0.8606741573033708, 0.9403669724562538] and parameters: {'lr': 4.7149306715795684e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 1489}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:50:12,140] Trial 16 finished with values: [0.7080062794348508, 0.9471365638537038] and parameters: {'lr': 1.4017512473074175e-05, 'batch_size': 32, 'num_epochs': 5, 'seed': 6243}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:50:31,186] Trial 17 finished with values: [0.837908496732026, 0.9360730593396615] and parameters: {'lr': 3.473469792074047e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 4177}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:50:48,796] Trial 18 finished with values: [0.6922489499809088, 0.929203539800278] and parameters: {'lr': 2.847143050592769e-05, 'batch_size': 16, 'num_epochs': 6, 'seed': 912}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:51:04,916] Trial 19 finished with values: [0.7232142857142857, 0.9333333333108247] and parameters: {'lr': 1.3612154661460227e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 1999}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:51:18,070] Trial 20 finished with values: [0.8141858141858143, 0.9318181817968594] and parameters: {'lr': 1.8223234484673633e-05, 'batch_size': 8, 'num_epochs': 4, 'seed': 2296}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:51:32,962] Trial 21 finished with values: [0.6770833333333333, 0.9111111110886025] and parameters: {'lr': 2.697245288917087e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 1268}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [I 2025-04-16 08:51:43,219] Trial 22 finished with values: [0.4095238095238095, 0.9188034187790743] and parameters: {'lr': 3.82760962441449e-05, 'batch_size': 16, 'num_epochs': 3, 'seed': 5094}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:51:59,304] Trial 23 finished with values: [0.8482252141982864, 0.9069767441660466] and parameters: {'lr': 3.1867650219142226e-05, 'batch_size': 8, 'num_epochs': 5, 'seed': 4483}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:52:14,506] Trial 24 finished with values: [0.7232142857142857, 0.9333333333108247] and parameters: {'lr': 1.3731607150580987e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 8246}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:52:23,938] Trial 25 finished with values: [0.7361702127659575, 0.9192825111887128] and parameters: {'lr': 1.1591207209490288e-05, 'batch_size': 16, 'num_epochs': 3, 'seed': 2540}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:52:34,132] Trial 26 finished with values: [0.8784313725490196, 0.9589041095679718] and parameters: {'lr': 3.879723266471018e-05, 'batch_size': 8, 'num_epochs': 3, 'seed': 641}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:52:43,581] Trial 27 finished with values: [0.7361702127659575, 0.9192825111887128] and parameters: {'lr': 3.3901215872121746e-05, 'batch_size': 16, 'num_epochs': 3, 'seed': 3399}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:53:02,686] Trial 28 finished with values: [0.8315217391304348, 0.9502262443223213] and parameters: {'lr': 4.2981540631737356e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 8638}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:53:17,572] Trial 29 finished with values: [0.6743434343434344, 0.94298245611719] and parameters: {'lr': 1.1751896625230288e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 1018}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:53:33,636] Trial 30 finished with values: [0.8064516129032258, 0.9459459459241338] and parameters: {'lr': 1.5566672462503094e-05, 'batch_size': 8, 'num_epochs': 5, 'seed': 9788}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:53:48,767] Trial 31 finished with values: [0.8266542404473439, 0.9027777777575017] and parameters: {'lr': 3.998367133572775e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 7526}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:54:05,856] Trial 32 finished with values: [0.8041917886879126, 0.8333333333148073] and parameters: {'lr': 3.3305064579114836e-05, 'batch_size': 32, 'num_epochs': 6, 'seed': 2052}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:54:18,970] Trial 33 finished with values: [0.6820512820512821, 0.7943925233447681] and parameters: {'lr': 1.0084580882853781e-05, 'batch_size': 8, 'num_epochs': 4, 'seed': 1037}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:54:36,628] Trial 34 finished with values: [0.6743434343434344, 0.94298245611719] and parameters: {'lr': 2.0405788025196704e-05, 'batch_size': 32, 'num_epochs': 3, 'seed': 7215}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:54:48,475] Trial 35 finished with values: [0.7894021739130435, 0.9276018099331812] and parameters: {'lr': 1.1880609806438318e-05, 'batch_size': 32, 'num_epochs': 4, 'seed': 4128}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:54:57,612] Trial 36 finished with values: [0.6743434343434344, 0.94298245611719] and parameters: {'lr': 3.617197126888698e-05, 'batch_size': 32, 'num_epochs': 3, 'seed': 8481}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:55:09,750] Trial 37 finished with values: [0.7801418439716312, 0.9417040358523899] and parameters: {'lr': 3.184072951441918e-05, 'batch_size': 16, 'num_epochs': 4, 'seed': 5844}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:55:21,571] Trial 38 finished with values: [0.6593406593406593, 0.9251101321356421] and parameters: {'lr': 1.5493492506987333e-05, 'batch_size': 32, 'num_epochs': 4, 'seed': 9739}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:55:48,777] Trial 39 finished with values: [0.6449026345933562, 0.9070796459949684] and parameters: {'lr': 1.721351072129307e-05, 'batch_size': 32, 'num_epochs': 6, 'seed': 6884}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:55:58,131] Trial 40 finished with values: [0.662431941923775, 0.8928571428348612] and parameters: {'lr': 1.198415335018085e-05, 'batch_size': 32, 'num_epochs': 3, 'seed': 9683}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:56:07,586] Trial 41 finished with values: [0.7524500907441016, 0.9374999999777183] and parameters: {'lr': 1.3575794178639808e-05, 'batch_size': 16, 'num_epochs': 3, 'seed': 1894}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:56:16,796] Trial 42 finished with values: [0.5866666666666667, 0.9170305676622204] and parameters: {'lr': 1.071696169520171e-05, 'batch_size': 32, 'num_epochs': 3, 'seed': 4759}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:56:31,708] Trial 43 finished with values: [0.6593406593406593, 0.9251101321356421] and parameters: {'lr': 1.1239795459946434e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 2795}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:56:47,820] Trial 44 finished with values: [0.7634408602150538, 0.923423423401611] and parameters: {'lr': 4.5553039627024666e-05, 'batch_size': 8, 'num_epochs': 5, 'seed': 3261}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [I 2025-04-16 08:57:02,759] Trial 45 finished with values: [0.4095238095238095, 0.9188034187790743] and parameters: {'lr': 1.9975397369324492e-05, 'batch_size': 16, 'num_epochs': 5, 'seed': 8322}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:57:11,977] Trial 46 finished with values: [0.6593406593406593, 0.9251101321356421] and parameters: {'lr': 1.1556591162560311e-05, 'batch_size': 32, 'num_epochs': 3, 'seed': 9164}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:57:24,303] Trial 47 finished with values: [0.6922489499809088, 0.929203539800278] and parameters: {'lr': 1.060035865433162e-05, 'batch_size': 16, 'num_epochs': 4, 'seed': 9691}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:57:36,149] Trial 48 finished with values: [0.6593406593406593, 0.9251101321356421] and parameters: {'lr': 1.0921781934401193e-05, 'batch_size': 32, 'num_epochs': 4, 'seed': 9325}.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-04-16 08:57:46,299] Trial 49 finished with values: [0.7524500907441016, 0.9374999999777183] and parameters: {'lr': 1.8654956277533062e-05, 'batch_size': 8, 'num_epochs': 3, 'seed': 2377}.
# ✅ Top Trials (F1-macro & F2-class1):
#
# Trial 0
# F1-macro: 0.9005, F2 (class 1): 0.9633
# Precision (0): 0.9375, Recall (0): 0.7895
# Precision (1): 0.9130, Recall (1): 0.9767
# Seed: 8425
# Confusion Matrix:
# [[15  4]
#  [ 1 42]]
#
# 🎯 Using best trial based on F1:
#   F1 = 0.9005, F2 = 0.9633
#   Params = {'lr': 3.118715542971209e-05, 'batch_size': 8, 'num_epochs': 6, 'seed': 8425}
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Final model saved as 'bert_cooperation_model_optimized_dual.pth'

# %%
from google.colab import drive
import os
import shutil

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Define the target folder in Google Drive
target_folder = '/content/drive/MyDrive/bert_predictions'
os.makedirs(target_folder, exist_ok=True)  # create it if it doesn't exist

# 3. Define the list of files you want to copy from Colab to Drive
files_to_save = [
    'bert_cooperation_model_optimized_dual.pth',
]

# 4. Copy files to the Google Drive folder
for file in files_to_save:
    if os.path.exists(file):
        shutil.copy(file, target_folder)
        print(f"✅ Copied: {file}")
    else:
        print(f"❌ File not found: {file}")
# Out:
# Mounted at /content/drive
# ✅ Copied: bert_cooperation_model_optimized_dual.pth
